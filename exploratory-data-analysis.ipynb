# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/world_internet_user.csv',encoding='unicode_escape')

# %%
df
# Out:
#              Country       Region  Population  Internet Users  % of Population
# 0             _World          NaN  7920539977      5424080321            68.48
# 1         Afganistan         Asia    40403518         9237489            22.86
# 2            Albania       Europe     2872758         2191467            76.28
# 3            Algeria       Africa    45150879        37836425            83.80
# 4     American Samoa      Oceania       54995           34800            63.28
# ..               ...          ...         ...             ...              ...
# 238  Wallis & Futuna      Oceania       10932            6200            56.71
# 239   Western Sahara       Africa      611875           28000             4.58
# 240            Yemen  Middle East    30938435         8353377            27.00
# 241           Zambia       Africa    18920651         9870427            52.17
# 242         Zimbabwe       Africa    15092171         8400000            55.66
#
# [243 rows x 5 columns]

# %%
df.skew()
# Out:
# <ipython-input-40-9e0b1e29546f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
#   df.skew()
# Population         14.216665
# Internet Users     14.269510
# % of Population    -0.799596
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 243 entries, 0 to 242
#
# Data columns (total 5 columns):
#
#  #   Column           Non-Null Count  Dtype
#
# ---  ------           --------------  -----
#
#  0   Country          243 non-null    object
#
#  1   Region           242 non-null    object
#
#  2   Population       243 non-null    int64
#
#  3   Internet Users   243 non-null    int64
#
#  4   % of Population  243 non-null    float64
#
# dtypes: float64(1), int64(2), object(2)
#
# memory usage: 9.6+ KB

# %%
df.shape
# Out:
# (243, 5)

# %%
df.isnull()
# Out:
#      Country  Region  Population  Internet Users  % of Population
# 0      False    True       False           False            False
# 1      False   False       False           False            False
# 2      False   False       False           False            False
# 3      False   False       False           False            False
# 4      False   False       False           False            False
# ..       ...     ...         ...             ...              ...
# 238    False   False       False           False            False
# 239    False   False       False           False            False
# 240    False   False       False           False            False
# 241    False   False       False           False            False
# 242    False   False       False           False            False
#
# [243 rows x 5 columns]

# %%
df.describe()
# Out:
#          Population  Internet Users  % of Population
# count  2.430000e+02    2.430000e+02       243.000000
# mean   6.518963e+07    4.464264e+07        69.921111
# std    5.235850e+08    3.579556e+08        27.426974
# min    5.960000e+02    4.140000e+02         0.080000
# 25%    3.321120e+05    2.049585e+05        52.190000
# 50%    5.302778e+06    2.864000e+06        77.940000
# 75%    2.025171e+07    9.898751e+06        91.010000
# max    7.920540e+09    5.424080e+09       120.700000

# %%
Internetusers_log=np.log(df['Internet Users'])
Internetusers_log.skew()
# Out:
# -0.4555320718616025

# %%
Population_log=np.log(df['Population'])
Population_log.skew()
# Out:
# -0.5819251402437251

# %%
df.drop_duplicates()
# Out:
#              Country       Region  Population  Internet Users  % of Population
# 0             _World          NaN  7920539977      5424080321            68.48
# 1         Afganistan         Asia    40403518         9237489            22.86
# 2            Albania       Europe     2872758         2191467            76.28
# 3            Algeria       Africa    45150879        37836425            83.80
# 4     American Samoa      Oceania       54995           34800            63.28
# ..               ...          ...         ...             ...              ...
# 238  Wallis & Futuna      Oceania       10932            6200            56.71
# 239   Western Sahara       Africa      611875           28000             4.58
# 240            Yemen  Middle East    30938435         8353377            27.00
# 241           Zambia       Africa    18920651         9870427            52.17
# 242         Zimbabwe       Africa    15092171         8400000            55.66
#
# [243 rows x 5 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# Length: 243, dtype: bool

# %%
df.isnull().sum()
# Out:
# Country            0
# Region             1
# Population         0
# Internet Users     0
# % of Population    0
# dtype: int64

# %%
df.Region.unique()
# Out:
# array([nan, 'Asia', 'Europe', 'Africa', 'Oceania', 'America',
#        'Middle East'], dtype=object)

# %%
df["Region"].fillna("No Region", inplace = True)
df
# Out:
#              Country       Region  Population  Internet Users  % of Population
# 0             _World    No Region  7920539977      5424080321            68.48
# 1         Afganistan         Asia    40403518         9237489            22.86
# 2            Albania       Europe     2872758         2191467            76.28
# 3            Algeria       Africa    45150879        37836425            83.80
# 4     American Samoa      Oceania       54995           34800            63.28
# ..               ...          ...         ...             ...              ...
# 238  Wallis & Futuna      Oceania       10932            6200            56.71
# 239   Western Sahara       Africa      611875           28000             4.58
# 240            Yemen  Middle East    30938435         8353377            27.00
# 241           Zambia       Africa    18920651         9870427            52.17
# 242         Zimbabwe       Africa    15092171         8400000            55.66
#
# [243 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Country            0
# Region             0
# Population         0
# Internet Users     0
# % of Population    0
# dtype: int64

# %%
df.plot()

# %%
df.drop(['Country','Region'],axis='columns',inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.corr()
# Out:
#                  Population  Internet Users  % of Population
# Population         1.000000        0.999308        -0.006565
# Internet Users     0.999308        1.000000         0.008268
# % of Population   -0.006565        0.008268         1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="pink")
plt.show()
